# %%
# !pip install opencv-python
# !pip install pytesseract
# !apt-get install -y tesseract-ocr
# !apt-get install -y libtesseract-dev
# !apt-get install -y tesseract-ocr-por
# Out:
# Requirement already satisfied: opencv-python in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.19.3 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from opencv-python) (2.1.3)
# Requirement already satisfied: pytesseract in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (0.3.13)
# Requirement already satisfied: Pillow>=8.0.0 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from pytesseract) (11.1.0)
# Requirement already satisfied: packaging>=21.3 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from pytesseract) (24.2)
# E: Não foi possível abrir arquivo de trava /var/lib/dpkg/lock-frontend - open (13: Permissão negada)
# E: Unable to acquire the dpkg frontend lock (/var/lib/dpkg/lock-frontend), are you root?
# E: Não foi possível abrir arquivo de trava /var/lib/dpkg/lock-frontend - open (13: Permissão negada)
# E: Unable to acquire the dpkg frontend lock (/var/lib/dpkg/lock-frontend), are you root?
# E: Não foi possível abrir arquivo de trava /var/lib/dpkg/lock-frontend - open (13: Permissão negada)
# E: Unable to acquire the dpkg frontend lock (/var/lib/dpkg/lock-frontend), are you root?

# %%
import pytesseract
import cv2

# Carregando a imagem
img = cv2.imread('content/ESPORTE.png')

if img is None:
	raise FileNotFoundError("A imagem '/content/ESPORTE.png' não foi encontrada. Verifique o caminho do arquivo.")

# Convertendo para escala de cinza
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Exibindo a imagem em escala de cinza
import matplotlib.pyplot as plt
plt.imshow(img_gray, cmap='gray')
plt.axis('off')
plt.show()

# Aplicando o Tesseract OCR
texto = pytesseract.image_to_string(img_gray, lang='por')
print(texto)
# Out:
# Você não pode colocar um limite
# em nada. Quanto mais você sonha,
#
# mais longe você chega.
#
# Michael Phelps

# %%
# Aplicando técnicas de thresholding
_, img_thresh = cv2.threshold(img_gray, 142, 255, cv2.THRESH_BINARY)
plt.imshow(img_thresh)
plt.axis('off')
plt.show()

# Extraindo texto após pré-processamento
texto_thresh = pytesseract.image_to_string(img_thresh, lang='por')
print(texto_thresh)
# Out:
#
#
# Você não pode colocar um limite
# em nada. Quanto mais você sonha,
# mais longe você chega.
#
#
#
#
#
#
#
#
# Michael Phelps

# %%
# Aplicando o método de Otsu
_, img_otsu = cv2.threshold(img_gray, 0, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)
plt.imshow(img_otsu)
plt.axis('off')
plt.show()

# Extraindo texto após pré-processamento
texto_otsu = pytesseract.image_to_string(img_otsu, lang='por')
print(texto_otsu)
# Out:
# Você não pode colocar um limite
# em nada. Quanto mais você sonha,
#
# mais longe você chega.
#
# Michael Phelps

# %%
# Aplicando limiarização adaptativa
img_adaptive_mean = cv2.adaptiveThreshold(img_gray, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 33, 9)
plt.imshow(img_adaptive_mean)
plt.axis('off')
plt.show()

# Extraindo texto após pré-processamento
texto_adaptive_mean = pytesseract.image_to_string(img_adaptive_mean, lang='por')
print(texto_adaptive_mean)
# Out:
#
#
#
#
# Você não pode colocar um limite
# em nada. Quanto mais você sonha,
# mais longe você chega.
#
#
#
#
#
# Michael Phelps

# %%
# Aplicando filtros para remoção de ruído
img_median_blur = cv2.medianBlur(img_gray, 3)
plt.imshow(img_median_blur)
plt.axis('off')
plt.show()

# Extraindo texto após pré-processamento
texto_median_blur = pytesseract.image_to_string(img_median_blur, lang='por')
print(texto_median_blur)
# Out:
# Você não pode colocar um limite
# em nada. Quanto mais você sonha,
#
# mais longe você chega.
#
# Michael Phelps

# %%
from difflib import SequenceMatcher

# Texto original
texto_original = """
Você não pode colocar um limite
em nada. Quanto mais você sonha,
mais longe você chega.

Michael Phelps
"""

# Variáveis que contêm os textos OCR a serem verificados
texto_ocr_variants = {
    "texto": texto,
    "texto_thresh": texto_thresh,
    "texto_otsu": texto_otsu,
    "texto_adaptive_mean": texto_adaptive_mean,
    "texto_median_blur": texto_median_blur,
}

def compare_texts(original, ocr_text):
    matcher = SequenceMatcher(None, original, ocr_text)
    match_ratio = matcher.ratio()
    return match_ratio

def main():
    original_len = len(texto_original)
    print(f"Quantidade de caracteres no texto original: {original_len}\n")

    for variant_name, ocr_text in texto_ocr_variants.items():
        ocr_len = len(ocr_text)
        accuracy = compare_texts(texto_original, ocr_text)
        accuracy_percentage = accuracy * 100

        print(f"Resultado para {variant_name}:")
        print(f"Quantidade de caracteres no texto OCR: {ocr_len}")
        print(f"Percentual de acertos: {accuracy_percentage:.2f}%\n")


if __name__ == "__main__":
    main()
# Out:
# Quantidade de caracteres no texto original: 105
#
# Resultado para texto:
# Quantidade de caracteres no texto OCR: 109
# Percentual de acertos: 97.20%
#
# Resultado para texto_thresh:
# Quantidade de caracteres no texto OCR: 127
# Percentual de acertos: 90.52%
#
# Resultado para texto_otsu:
# Quantidade de caracteres no texto OCR: 109
# Percentual de acertos: 97.20%
#
# Resultado para texto_adaptive_mean:
# Quantidade de caracteres no texto OCR: 129
# Percentual de acertos: 89.74%
#
# Resultado para texto_median_blur:
# Quantidade de caracteres no texto OCR: 109
# Percentual de acertos: 97.20%

# %%
# !pip install paddleocr paddlepaddle pdf2image
#sudo apt-get install poppler-utils
# Out:
# Requirement already satisfied: paddleocr in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (3.0.1)
# Requirement already satisfied: paddlepaddle in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (3.0.0)
# Collecting pdf2image
#   Downloading pdf2image-1.17.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: typing-extensions>=4.12 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddleocr) (4.13.1)
# Requirement already satisfied: PyYAML>=6 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddleocr) (6.0.2)
# Requirement already satisfied: paddlex[ie,multimodal,ocr]==3.0.1 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddleocr) (3.0.1)
# Requirement already satisfied: py-cpuinfo in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (9.0.0)
# Requirement already satisfied: GPUtil>=1.4 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (1.4.0)
# Requirement already satisfied: prettytable in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (3.16.0)
# Requirement already satisfied: packaging in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (24.2)
# Requirement already satisfied: pydantic>=2 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (2.11.3)
# Requirement already satisfied: ruamel.yaml in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (0.18.12)
# Requirement already satisfied: filelock in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (3.18.0)
# Requirement already satisfied: colorlog in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (6.9.0)
# Requirement already satisfied: chardet in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (5.2.0)
# Requirement already satisfied: ujson in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (5.10.0)
# Requirement already satisfied: pillow in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (11.1.0)
# Requirement already satisfied: requests in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (2.32.3)
# Requirement already satisfied: numpy==1.24.4 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (1.24.4)
# Requirement already satisfied: pandas<=1.5.3 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (1.5.3)
# Requirement already satisfied: ftfy in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (6.3.1)
# Requirement already satisfied: tiktoken in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (0.9.0)
# Requirement already satisfied: regex in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (2024.11.6)
# Requirement already satisfied: einops in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (0.8.1)
# Requirement already satisfied: opencv-contrib-python==4.10.0.84 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (4.10.0.84)
# Requirement already satisfied: Jinja2 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (3.1.6)
# Requirement already satisfied: pypdfium2>=4 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (4.30.1)
# Requirement already satisfied: openpyxl in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (3.1.5)
# Requirement already satisfied: pyclipper in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (1.3.0.post6)
# Requirement already satisfied: premailer in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (3.10.0)
# Requirement already satisfied: tokenizers==0.19.1 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (0.19.1)
# Requirement already satisfied: imagesize in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (1.4.1)
# Requirement already satisfied: shapely in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (2.1.1)
# Requirement already satisfied: scikit-learn in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (1.6.1)
# Requirement already satisfied: lxml in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (5.4.0)
# Requirement already satisfied: langchain-core in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (0.2.43)
# Requirement already satisfied: langchain==0.2.17 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (0.2.17)
# Requirement already satisfied: langchain-openai==0.1.25 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (0.1.25)
# Requirement already satisfied: langchain-community==0.2.17 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (0.2.17)
# Requirement already satisfied: openai==1.63.2 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (1.63.2)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from langchain==0.2.17->paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (0.2.4)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from langchain==0.2.17->paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (0.1.147)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from langchain==0.2.17->paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (3.11.18)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from langchain==0.2.17->paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (4.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from langchain==0.2.17->paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (8.5.0)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from langchain==0.2.17->paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (2.0.40)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from langchain-community==0.2.17->paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (0.6.7)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from openai==1.63.2->paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (0.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from openai==1.63.2->paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from openai==1.63.2->paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (0.28.1)
# Requirement already satisfied: tqdm>4 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from openai==1.63.2->paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (4.67.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from openai==1.63.2->paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (4.9.0)
# Requirement already satisfied: sniffio in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from openai==1.63.2->paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (1.3.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from tokenizers==0.19.1->paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (0.30.2)
# Requirement already satisfied: opt_einsum==3.3.0 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddlepaddle) (3.3.0)
# Requirement already satisfied: decorator in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddlepaddle) (5.2.1)
# Requirement already satisfied: networkx in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddlepaddle) (3.4.2)
# Requirement already satisfied: astor in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddlepaddle) (0.8.1)
# Requirement already satisfied: protobuf>=3.20.2 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddlepaddle) (4.21.12)
# Requirement already satisfied: httpcore==1.* in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai==1.63.2->paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (1.0.8)
# Requirement already satisfied: idna in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai==1.63.2->paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (3.10)
# Requirement already satisfied: certifi in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai==1.63.2->paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (2025.1.31)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai==1.63.2->paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (0.14.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai==1.63.2->paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (1.2.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from langchain-core->paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (1.33)
# Requirement already satisfied: pytz>=2020.1 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from pandas<=1.5.3->paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (2025.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from pandas<=1.5.3->paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (2.9.0.post0)
# Requirement already satisfied: pydantic-core==2.33.1 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from pydantic>=2->paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (2.33.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from pydantic>=2->paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from pydantic>=2->paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from requests->paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from requests->paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (2.4.0)
# Requirement already satisfied: wcwidth in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from ftfy->paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (0.2.13)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from Jinja2->paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (3.0.2)
# Requirement already satisfied: et-xmlfile in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from openpyxl->paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (2.0.0)
# Requirement already satisfied: cssutils in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from premailer->paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (2.11.1)
# Requirement already satisfied: cssselect in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from premailer->paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (1.3.0)
# Requirement already satisfied: cachetools in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from premailer->paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (5.5.2)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from ruamel.yaml->paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (0.2.12)
# Requirement already satisfied: scipy>=1.6.0 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from scikit-learn->paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from scikit-learn->paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from scikit-learn->paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (3.6.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.17->paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.17->paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (1.6.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.17->paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (1.20.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.17->paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (1.3.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.17->paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (2.6.1)
# Requirement already satisfied: propcache>=0.2.0 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.17->paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (0.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.17->paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (6.4.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.2.17->paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.2.17->paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (0.9.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers==0.19.1->paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (2025.3.2)
# Requirement already satisfied: jsonpointer>=1.9 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain-core->paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (3.0.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.2.17->paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (1.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.2.17->paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (3.10.16)
# Requirement already satisfied: six>=1.5 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas<=1.5.3->paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (1.17.0)
# Requirement already satisfied: greenlet>=1 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from SQLAlchemy<3,>=1.4->langchain==0.2.17->paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (3.2.1)
# Requirement already satisfied: more-itertools in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from cssutils->premailer->paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (10.7.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community==0.2.17->paddlex[ie,multimodal,ocr]==3.0.1->paddleocr) (1.1.0)
# Installing collected packages: pdf2image
# Successfully installed pdf2image-1.17.0
# [sudo] senha para lucas:
# sudo: uma senha é necessária
# ^C

# %%
# %pip install --upgrade paddlepaddle==2.4.2
# %pip install paddleocr==2.6.1.3 pdf2image
# Out:
# Requirement already satisfied: paddlepaddle==2.4.2 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (2.4.2)
# Requirement already satisfied: paddle-bfloat==0.1.7 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddlepaddle==2.4.2) (0.1.7)
# Requirement already satisfied: decorator in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddlepaddle==2.4.2) (5.2.1)
# Requirement already satisfied: Pillow in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddlepaddle==2.4.2) (11.1.0)
# Requirement already satisfied: six in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddlepaddle==2.4.2) (1.17.0)
# Requirement already satisfied: numpy>=1.13 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddlepaddle==2.4.2) (1.24.4)
# Requirement already satisfied: opt-einsum==3.3.0 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddlepaddle==2.4.2) (3.3.0)
# Requirement already satisfied: protobuf<=3.20.0,>=3.1.0 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddlepaddle==2.4.2) (3.20.0)
# Requirement already satisfied: requests>=2.20.0 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddlepaddle==2.4.2) (2.32.3)
# Requirement already satisfied: astor in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddlepaddle==2.4.2) (0.8.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from requests>=2.20.0->paddlepaddle==2.4.2) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from requests>=2.20.0->paddlepaddle==2.4.2) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from requests>=2.20.0->paddlepaddle==2.4.2) (2025.1.31)
# Requirement already satisfied: idna<4,>=2.5 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from requests>=2.20.0->paddlepaddle==2.4.2) (3.10)
# Note: you may need to restart the kernel to use updated packages.
# Collecting paddleocr==2.6.1.3
#   Downloading paddleocr-2.6.1.3-py3-none-any.whl (445 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 445.9/445.9 KB 4.3 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: pdf2image in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (1.17.0)
# Collecting opencv-contrib-python<=4.6.0.66
#   Using cached opencv_contrib_python-4.6.0.66-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (67.1 MB)
# Requirement already satisfied: scikit-image in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddleocr==2.6.1.3) (0.25.2)
# Requirement already satisfied: visualdl in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddleocr==2.6.1.3) (2.5.3)
# Requirement already satisfied: lxml in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddleocr==2.6.1.3) (5.4.0)
# Requirement already satisfied: fonttools>=4.24.0 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddleocr==2.6.1.3) (4.57.0)
# Requirement already satisfied: numpy in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddleocr==2.6.1.3) (1.24.4)
# Requirement already satisfied: python-docx in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddleocr==2.6.1.3) (1.1.2)
# Requirement already satisfied: shapely in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddleocr==2.6.1.3) (2.1.1)
# Requirement already satisfied: openpyxl in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddleocr==2.6.1.3) (3.1.5)
# Requirement already satisfied: pdf2docx in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddleocr==2.6.1.3) (0.5.8)
# Requirement already satisfied: fire>=0.3.0 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddleocr==2.6.1.3) (0.7.0)
# Requirement already satisfied: premailer in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddleocr==2.6.1.3) (3.10.0)
# Requirement already satisfied: pyclipper in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddleocr==2.6.1.3) (1.3.0.post6)
# Requirement already satisfied: beautifulsoup4 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddleocr==2.6.1.3) (4.13.4)
# Requirement already satisfied: rapidfuzz in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddleocr==2.6.1.3) (3.13.0)
# Requirement already satisfied: imgaug in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddleocr==2.6.1.3) (0.4.0)
# Requirement already satisfied: cython in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddleocr==2.6.1.3) (3.1.1)
# Requirement already satisfied: attrdict in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddleocr==2.6.1.3) (2.0.1)
# Requirement already satisfied: lmdb in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddleocr==2.6.1.3) (1.6.2)
# Requirement already satisfied: tqdm in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddleocr==2.6.1.3) (4.67.1)
# Collecting PyMuPDF<1.21.0
#   Downloading PyMuPDF-1.20.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 10.3 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: opencv-python<=4.6.0.66 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from paddleocr==2.6.1.3) (4.6.0.66)
# Requirement already satisfied: pillow in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from pdf2image) (11.1.0)
# Requirement already satisfied: termcolor in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from fire>=0.3.0->paddleocr==2.6.1.3) (3.0.1)
# Requirement already satisfied: six in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from attrdict->paddleocr==2.6.1.3) (1.17.0)
# Requirement already satisfied: soupsieve>1.2 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from beautifulsoup4->paddleocr==2.6.1.3) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from beautifulsoup4->paddleocr==2.6.1.3) (4.13.1)
# Requirement already satisfied: imageio in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from imgaug->paddleocr==2.6.1.3) (2.37.0)
# Requirement already satisfied: matplotlib in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from imgaug->paddleocr==2.6.1.3) (3.10.1)
# Requirement already satisfied: scipy in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from imgaug->paddleocr==2.6.1.3) (1.15.2)
# Requirement already satisfied: lazy-loader>=0.4 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from scikit-image->paddleocr==2.6.1.3) (0.4)
# Requirement already satisfied: tifffile>=2022.8.12 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from scikit-image->paddleocr==2.6.1.3) (2025.5.10)
# Requirement already satisfied: networkx>=3.0 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from scikit-image->paddleocr==2.6.1.3) (3.4.2)
# Requirement already satisfied: packaging>=21 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from scikit-image->paddleocr==2.6.1.3) (24.2)
# Requirement already satisfied: et-xmlfile in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from openpyxl->paddleocr==2.6.1.3) (2.0.0)
# Requirement already satisfied: opencv-python-headless>=4.5 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from pdf2docx->paddleocr==2.6.1.3) (4.11.0.86)
# Requirement already satisfied: requests in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from premailer->paddleocr==2.6.1.3) (2.32.3)
# Requirement already satisfied: cssutils in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from premailer->paddleocr==2.6.1.3) (2.11.1)
# Requirement already satisfied: cssselect in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from premailer->paddleocr==2.6.1.3) (1.3.0)
# Requirement already satisfied: cachetools in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from premailer->paddleocr==2.6.1.3) (5.5.2)
# Requirement already satisfied: protobuf>=3.20.0 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from visualdl->paddleocr==2.6.1.3) (3.20.0)
# Requirement already satisfied: rarfile in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from visualdl->paddleocr==2.6.1.3) (4.2)
# Requirement already satisfied: bce-python-sdk in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from visualdl->paddleocr==2.6.1.3) (0.9.35)
# Requirement already satisfied: Flask-Babel>=3.0.0 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from visualdl->paddleocr==2.6.1.3) (4.0.0)
# Requirement already satisfied: pandas in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from visualdl->paddleocr==2.6.1.3) (1.5.3)
# Requirement already satisfied: psutil in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from visualdl->paddleocr==2.6.1.3) (7.0.0)
# Requirement already satisfied: flask>=1.1.1 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from visualdl->paddleocr==2.6.1.3) (3.1.1)
# Requirement already satisfied: blinker>=1.9.0 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from flask>=1.1.1->visualdl->paddleocr==2.6.1.3) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from flask>=1.1.1->visualdl->paddleocr==2.6.1.3) (8.1.8)
# Requirement already satisfied: jinja2>=3.1.2 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from flask>=1.1.1->visualdl->paddleocr==2.6.1.3) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.2.0 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from flask>=1.1.1->visualdl->paddleocr==2.6.1.3) (2.2.0)
# Requirement already satisfied: werkzeug>=3.1.0 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from flask>=1.1.1->visualdl->paddleocr==2.6.1.3) (3.1.3)
# Requirement already satisfied: markupsafe>=2.1.1 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from flask>=1.1.1->visualdl->paddleocr==2.6.1.3) (3.0.2)
# Requirement already satisfied: Babel>=2.12 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from Flask-Babel>=3.0.0->visualdl->paddleocr==2.6.1.3) (2.17.0)
# Requirement already satisfied: pytz>=2022.7 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from Flask-Babel>=3.0.0->visualdl->paddleocr==2.6.1.3) (2025.2)
# Requirement already satisfied: future>=0.6.0 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from bce-python-sdk->visualdl->paddleocr==2.6.1.3) (1.0.0)
# Requirement already satisfied: pycryptodome>=3.8.0 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from bce-python-sdk->visualdl->paddleocr==2.6.1.3) (3.23.0)
# Requirement already satisfied: more-itertools in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from cssutils->premailer->paddleocr==2.6.1.3) (10.7.0)
# Requirement already satisfied: cycler>=0.10 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from matplotlib->imgaug->paddleocr==2.6.1.3) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from matplotlib->imgaug->paddleocr==2.6.1.3) (1.4.8)
# Requirement already satisfied: contourpy>=1.0.1 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from matplotlib->imgaug->paddleocr==2.6.1.3) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from matplotlib->imgaug->paddleocr==2.6.1.3) (2.9.0.post0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from matplotlib->imgaug->paddleocr==2.6.1.3) (3.2.3)
# Requirement already satisfied: idna<4,>=2.5 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from requests->premailer->paddleocr==2.6.1.3) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from requests->premailer->paddleocr==2.6.1.3) (2025.1.31)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from requests->premailer->paddleocr==2.6.1.3) (2.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/lucas/Study/projects/IA-Studies/venv/lib/python3.10/site-packages (from requests->premailer->paddleocr==2.6.1.3) (3.4.1)
# Installing collected packages: PyMuPDF, opencv-contrib-python, paddleocr
#   Attempting uninstall: PyMuPDF
#     Found existing installation: PyMuPDF 1.26.0
#     Uninstalling PyMuPDF-1.26.0:
#       Successfully uninstalled PyMuPDF-1.26.0
#   Attempting uninstall: opencv-contrib-python
#     Found existing installation: opencv-contrib-python 4.10.0.84
#     Uninstalling opencv-contrib-python-4.10.0.84:
#       Successfully uninstalled opencv-contrib-python-4.10.0.84
#   Attempting uninstall: paddleocr
#     Found existing installation: paddleocr 3.0.1
#     Uninstalling paddleocr-3.0.1:
#       Successfully uninstalled paddleocr-3.0.1
# Successfully installed PyMuPDF-1.20.2 opencv-contrib-python-4.6.0.66 paddleocr-2.6.1.3
# Note: you may need to restart the kernel to use updated packages.

# %%
from paddleocr import PaddleOCR
from pdf2image import convert_from_path
import os

# Inicializa o OCR
ocr = PaddleOCR(use_angle_cls=True, lang='en')

def extract_text_from_pdf(pdf_path):
    # Converte PDF em imagens (uma por página)
    pages = convert_from_path(pdf_path)
    result = ''
    for i, page in enumerate(pages):
        # Salva página temporariamente como imagem
        img_path = f'temp_page_{i}.png'
        page.save(img_path, 'PNG')
        # OCR na imagem
        ocr_result = ocr.ocr(img_path)
        for line in ocr_result:
            for word in line:
                result += word[1][0] + ' '
            result += '\n'
        os.remove(img_path)
    return result

# Caminho para o arquivo PDF
pdf_path = "/content/conta_enel_ficticia.pdf"

# Extrai texto do PDF usando OCR
ocr_text = extract_text_from_pdf(pdf_path)
print(ocr_text)
# Out:
# /tmp/ipykernel_452439/3133613708.py:6: DeprecationWarning: The parameter `use_angle_cls` has been deprecated and will be removed in the future. Please use `use_textline_orientation` instead.
#   ocr = PaddleOCR(use_angle_cls=True, lang='en')
# Creating model: ('PP-LCNet_x1_0_doc_ori', None)
# Using official model (PP-LCNet_x1_0_doc_ori), the model files will be automatically downloaded and saved in /home/lucas/.paddlex/official_models.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 6
#       3 import os
#       5 # Inicializa o OCR
# ----> 6 ocr = PaddleOCR(use_angle_cls=True, lang='en')
#       8 def extract_text_from_pdf(pdf_path):
#       9     # Converte PDF em imagens (uma por página)
#      10     pages = convert_from_path(pdf_path)
#
# File ~/Study/projects/IA-Studies/venv/lib/python3.10/site-packages/paddleocr/_pipelines/ocr.py:161, in PaddleOCR.__init__(self, doc_orientation_classify_model_name, doc_orientation_classify_model_dir, doc_unwarping_model_name, doc_unwarping_model_dir, text_detection_model_name, text_detection_model_dir, textline_orientation_model_name, textline_orientation_model_dir, textline_orientation_batch_size, text_recognition_model_name, text_recognition_model_dir, text_recognition_batch_size, use_doc_orientation_classify, use_doc_unwarping, use_textline_orientation, text_det_limit_side_len, text_det_limit_type, text_det_thresh, text_det_box_thresh, text_det_unclip_ratio, text_det_input_shape, text_rec_score_thresh, text_rec_input_shape, lang, ocr_version, **kwargs)
#     157         base_params[name] = val
#     159 self._params = params
# --> 161 super().__init__(**base_params)
#
# File ~/Study/projects/IA-Studies/venv/lib/python3.10/site-packages/paddleocr/_pipelines/base.py:63, in PaddleXPipelineWrapper.__init__(self, paddlex_config, **common_args)
#      59 self._common_args = parse_common_args(
#      60     common_args, default_enable_hpi=_DEFAULT_ENABLE_HPI
#      61 )
#      62 self._merged_paddlex_config = self._get_merged_paddlex_config()
# ---> 63 self.paddlex_pipeline = self._create_paddlex_pipeline()
#
# File ~/Study/projects/IA-Studies/venv/lib/python3.10/site-packages/paddleocr/_pipelines/base.py:97, in PaddleXPipelineWrapper._create_paddlex_pipeline(self)
#      95 def _create_paddlex_pipeline(self):
#      96     kwargs = prepare_common_init_args(None, self._common_args)
# ---> 97     return create_pipeline(config=self._merged_paddlex_config, **kwargs)
#
# File ~/Study/projects/IA-Studies/venv/lib/python3.10/site-packages/paddlex/inference/pipelines/__init__.py:165, in create_pipeline(pipeline, config, device, pp_option, use_hpip, hpi_config, *args, **kwargs)
#     162 else:
#     163     config.pop("hpi_config", None)
# --> 165 pipeline = BasePipeline.get(pipeline_name)(
#     166     config=config,
#     167     device=device,
#     168     pp_option=pp_option,
#     169     use_hpip=use_hpip,
#     170     hpi_config=hpi_config,
#     171     *args,
#     172     **kwargs,
#     173 )
#     174 return pipeline
#
# File ~/Study/projects/IA-Studies/venv/lib/python3.10/site-packages/paddlex/utils/deps.py:195, in pipeline_requires_extra.<locals>._deco.<locals>._wrapper(self, *args, **kwargs)
#     192 @wraps(pipeline_cls.__init__)
#     193 def _wrapper(self, *args, **kwargs):
#     194     require_extra(extra, obj_name=pipeline_name)
# --> 195     return old_init_func(self, *args, **kwargs)
#
# File ~/Study/projects/IA-Studies/venv/lib/python3.10/site-packages/paddlex/inference/pipelines/_parallel.py:103, in AutoParallelSimpleInferencePipeline.__init__(self, config, *args, **kwargs)
#      97         self._executor = MultiDeviceSimpleInferenceExecutor(
#      98             self._pipelines,
#      99             batch_sampler,
#     100             postprocess_result=self._postprocess_result,
#     101         )
#     102 if not self._multi_device_inference:
# --> 103     self._pipeline = self._create_internal_pipeline(config, self.device)
#
# File ~/Study/projects/IA-Studies/venv/lib/python3.10/site-packages/paddlex/inference/pipelines/_parallel.py:158, in AutoParallelImageSimpleInferencePipeline._create_internal_pipeline(self, config, device)
#     157 def _create_internal_pipeline(self, config, device):
# --> 158     return self._pipeline_cls(
#     159         config,
#     160         device=device,
#     161         pp_option=self.pp_option,
#     162         use_hpip=self.use_hpip,
#     163         hpi_config=self.hpi_config,
#     164     )
#
# File ~/Study/projects/IA-Studies/venv/lib/python3.10/site-packages/paddlex/inference/pipelines/ocr/pipeline.py:73, in _OCRPipeline.__init__(self, config, device, pp_option, use_hpip, hpi_config)
#      66 if self.use_doc_preprocessor:
#      67     doc_preprocessor_config = config.get("SubPipelines", {}).get(
#      68         "DocPreprocessor",
#      69         {
#      70             "pipeline_config_error": "config error for doc_preprocessor_pipeline!"
#      71         },
#      72     )
# ---> 73     self.doc_preprocessor_pipeline = self.create_pipeline(
#      74         doc_preprocessor_config
#      75     )
#      77 self.use_textline_orientation = config.get("use_textline_orientation", True)
#      78 if self.use_textline_orientation:
#
# File ~/Study/projects/IA-Studies/venv/lib/python3.10/site-packages/paddlex/inference/pipelines/base.py:140, in BasePipeline.create_pipeline(self, config)
#     137     hpi_config = hpi_config or {}
#     138     hpi_config = {**self.hpi_config, **hpi_config}
# --> 140 pipeline = create_pipeline(
#     141     config=config,
#     142     device=self.device,
#     143     pp_option=(
#     144         self.pp_option.copy() if self.pp_option is not None else self.pp_option
#     145     ),
#     146     use_hpip=use_hpip,
#     147     hpi_config=hpi_config,
#     148 )
#     149 return pipeline
#
# File ~/Study/projects/IA-Studies/venv/lib/python3.10/site-packages/paddlex/inference/pipelines/__init__.py:165, in create_pipeline(pipeline, config, device, pp_option, use_hpip, hpi_config, *args, **kwargs)
#     162 else:
#     163     config.pop("hpi_config", None)
# --> 165 pipeline = BasePipeline.get(pipeline_name)(
#     166     config=config,
#     167     device=device,
#     168     pp_option=pp_option,
#     169     use_hpip=use_hpip,
#     170     hpi_config=hpi_config,
#     171     *args,
#     172     **kwargs,
#     173 )
#     174 return pipeline
#
# File ~/Study/projects/IA-Studies/venv/lib/python3.10/site-packages/paddlex/utils/deps.py:195, in pipeline_requires_extra.<locals>._deco.<locals>._wrapper(self, *args, **kwargs)
#     192 @wraps(pipeline_cls.__init__)
#     193 def _wrapper(self, *args, **kwargs):
#     194     require_extra(extra, obj_name=pipeline_name)
# --> 195     return old_init_func(self, *args, **kwargs)
#
# File ~/Study/projects/IA-Studies/venv/lib/python3.10/site-packages/paddlex/inference/pipelines/_parallel.py:103, in AutoParallelSimpleInferencePipeline.__init__(self, config, *args, **kwargs)
#      97         self._executor = MultiDeviceSimpleInferenceExecutor(
#      98             self._pipelines,
#      99             batch_sampler,
#     100             postprocess_result=self._postprocess_result,
#     101         )
#     102 if not self._multi_device_inference:
# --> 103     self._pipeline = self._create_internal_pipeline(config, self.device)
#
# File ~/Study/projects/IA-Studies/venv/lib/python3.10/site-packages/paddlex/inference/pipelines/_parallel.py:158, in AutoParallelImageSimpleInferencePipeline._create_internal_pipeline(self, config, device)
#     157 def _create_internal_pipeline(self, config, device):
# --> 158     return self._pipeline_cls(
#     159         config,
#     160         device=device,
#     161         pp_option=self.pp_option,
#     162         use_hpip=self.use_hpip,
#     163         hpi_config=self.hpi_config,
#     164     )
#
# File ~/Study/projects/IA-Studies/venv/lib/python3.10/site-packages/paddlex/inference/pipelines/doc_preprocessor/pipeline.py:67, in _DocPreprocessorPipeline.__init__(self, config, device, pp_option, use_hpip, hpi_config)
#      62 if self.use_doc_orientation_classify:
#      63     doc_ori_classify_config = config.get("SubModules", {}).get(
#      64         "DocOrientationClassify",
#      65         {"model_config_error": "config error for doc_ori_classify_model!"},
#      66     )
# ---> 67     self.doc_ori_classify_model = self.create_model(doc_ori_classify_config)
#      69 self.use_doc_unwarping = config.get("use_doc_unwarping", True)
#      70 if self.use_doc_unwarping:
#
# File ~/Study/projects/IA-Studies/venv/lib/python3.10/site-packages/paddlex/inference/pipelines/base.py:107, in BasePipeline.create_model(self, config, **kwargs)
#     104 else:
#     105     pp_option = None
# --> 107 model = create_predictor(
#     108     model_name=config["model_name"],
#     109     model_dir=model_dir,
#     110     device=self.device,
#     111     batch_size=config.get("batch_size", 1),
#     112     pp_option=pp_option,
#     113     use_hpip=use_hpip,
#     114     hpi_config=hpi_config,
#     115     **kwargs,
#     116 )
#     117 return model
#
# File ~/Study/projects/IA-Studies/venv/lib/python3.10/site-packages/paddlex/inference/models/__init__.py:77, in create_predictor(model_name, model_dir, device, pp_option, use_hpip, hpi_config, *args, **kwargs)
#      73 config = BasePredictor.load_config(model_dir)
#      74 assert (
#      75     model_name == config["Global"]["model_name"]
#      76 ), f"Model name mismatch，please input the correct model dir."
# ---> 77 return BasePredictor.get(model_name)(
#      78     model_dir=model_dir,
#      79     config=config,
#      80     device=device,
#      81     pp_option=pp_option,
#      82     use_hpip=use_hpip,
#      83     hpi_config=hpi_config,
#      84     *args,
#      85     **kwargs,
#      86 )
#
# File ~/Study/projects/IA-Studies/venv/lib/python3.10/site-packages/paddlex/inference/models/image_classification/predictor.py:49, in ClasPredictor.__init__(self, topk, *args, **kwargs)
#      47 super().__init__(*args, **kwargs)
#      48 self.topk = topk
# ---> 49 self.preprocessors, self.infer, self.postprocessors = self._build()
#
# File ~/Study/projects/IA-Studies/venv/lib/python3.10/site-packages/paddlex/inference/models/image_classification/predictor.py:82, in ClasPredictor._build(self)
#      79     preprocessors[name] = op
#      80 preprocessors["ToBatch"] = ToBatch()
# ---> 82 infer = self.create_static_infer()
#      84 postprocessors = {}
#      85 for key in self.config["PostProcess"]:
#
# File ~/Study/projects/IA-Studies/venv/lib/python3.10/site-packages/paddlex/inference/models/base/predictor/base_predictor.py:240, in BasePredictor.create_static_infer(self)
#     238 def create_static_infer(self):
#     239     if not self._use_hpip:
# --> 240         return PaddleInfer(self.model_dir, self.MODEL_FILE_PREFIX, self._pp_option)
#     241     else:
#     242         return HPInfer(
#     243             self.model_dir,
#     244             self.MODEL_FILE_PREFIX,
#     245             self._hpi_config,
#     246         )
#
# File ~/Study/projects/IA-Studies/venv/lib/python3.10/site-packages/paddlex/inference/models/common/static_infer.py:274, in PaddleInfer.__init__(self, model_dir, model_file_prefix, option)
#     272 self.model_file_prefix = model_file_prefix
#     273 self._option = option
# --> 274 self.predictor = self._create()
#     275 self.infer = PaddleInferChainLegacy(self.predictor)
#
# File ~/Study/projects/IA-Studies/venv/lib/python3.10/site-packages/paddlex/inference/models/common/static_infer.py:428, in PaddleInfer._create(self)
#     426         if hasattr(config, "enable_new_executor"):
#     427             config.enable_new_executor()
# --> 428         config.set_optimization_level(3)
#     430 config.enable_memory_optim()
#     431 for del_p in self._option.delete_pass:
#
# AttributeError: 'paddle.base.libpaddle.AnalysisConfig' object has no attribute 'set_optimization_level'

# %%
import re

# Expressões regulares para encontrar padrões específicos
padrao_cpf_cnpj = r"CPF/ CNPJ:\s([\d.-]+)"
padrao_nome_cliente = r"CPF:\s([\w\s]+)\s\d{3}\.\d{3}\.\d{3}-\d{2}"
padrao_num_cliente = r"NDO CLIENTE\s(\d+)"
padrao_data_leitura = r"DataLeitor\sLeitura\s(\d{2}/\d{2}/\d{4})"
padrao_data_vencimento = r"MES/AN\sVENCIMENT\sTOTAL\sA\sPAGAF\s(\d{2}/\d{4}\s\d{2}/\d{2}/\d{4})"
padrao_valor_total = r"R\$(\d+,\d{2})"
padrao_descricao_faturamento = r"DESCRICAO DO FATURAMENTO(.*?)MENTOS DE MEI"
padrao_referencia_faturamento = r"Referencia\s(\d{2}/\d{4}\s\d{2}/\d{2}/\d{4})"
padrao_qr_code = r"Pague via PIX! Utilize este QR Code"

# Função para extrair informações com base nos padrões de expressão regular
def extrair_informacoes(texto, padrao):
    match = re.search(padrao, texto)
    if match:
        return match.group(1)
    else:
        return None

# Extrair informações
cpf_cnpj = extrair_informacoes(ocr_text, padrao_cpf_cnpj)
nome_cliente = extrair_informacoes(ocr_text, padrao_nome_cliente)
num_cliente = extrair_informacoes(ocr_text, padrao_num_cliente)
data_vencimento = extrair_informacoes(ocr_text, padrao_data_vencimento)
valor_total = extrair_informacoes(ocr_text, padrao_valor_total)
referencia_faturamento = extrair_informacoes(ocr_text, padrao_referencia_faturamento)

# Verificar se há QR Code presente
qr_code_presente = re.search(padrao_qr_code, ocr_text) is not None

# Exibir informações extraídas
print("Nome do Cliente:", nome_cliente)
print("CPF/CNPJ:", cpf_cnpj)
print("Número do cliente:", num_cliente)
print("Data de vencimento:", data_vencimento)
print("Valor total:", valor_total)
print("Referência do faturamento:", referencia_faturamento)
print("QR Code presente:", qr_code_presente)
